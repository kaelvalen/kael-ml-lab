# %% [markdown]
# ## 2.3 Linear Algebra

# %% [markdown]
# ### Introduction to Linear Algebra for Deep Learning
#
# We now know how to load datasets into tensors and perform basic mathematical operations on them. To build more advanced models, we need tools from **linear algebra**.
#
# This section provides an introduction to key concepts in linear algebra, starting with **scalar arithmetic** and progressing to **matrix multiplication**.
