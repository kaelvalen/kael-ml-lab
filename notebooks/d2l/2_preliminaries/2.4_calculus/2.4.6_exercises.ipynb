# %% [markdown]
# # 2.4.6 Exercises

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import d2l

# %% [markdown]
# ## 1. Derivative Properties from First Principles
# So far we took the rules for derivatives for granted. Using the definition and limits prove the properties for:
# - (i) f(x) = c
# - (ii) f(x) = xⁿ
# - (iii) f(x) = eˣ
# - (iv) f(x) = log x

# %% [markdown]
# ## 2. Basic Differentiation Rules
# In the same vein, prove the product, sum, and quotient rule from first principles.

# %% [markdown]
# ## 3. Constant Multiple Rule
# Prove that the constant multiple rule follows as a special case of the product rule.

# %% [markdown]
# ## 4. Power Function Derivative
# Calculate the derivative of f(x) = xˣ.

# %%
# derivative of x ** x
def f(x):
    return x ** x 

df = autograd.grad(f)
df(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       2 def f(x):
#       3     return x ** x
# ----> 5 df = autograd.grad(f)
#       6 df(1)
#
# NameError: name 'autograd' is not defined

# %% [markdown]
# ## 5. Zero Derivative Interpretation
# What does it mean that f'(x) = 0 for some x? Give an example of a function f and a location x for which this might hold.

# %% [markdown]
# - f(x) = c
# - f(x) = cx for x = 0

# %% [markdown]
# ## 6. Plotting and Tangent Line
# Plot the function y = f(x) = x³ - 1/x and plot its tangent line at x = 1.

# %% [markdown]
# ## 7. Gradient Calculation
# Find the gradient of the function f(x) = 3x₁² - 5eˣ².

# %% [markdown]
# ## 8. Norm Gradient
# What is the gradient of the function f(x) = ‖x‖²? What happens for x = 0?

# %% [markdown]
# ## 9. Chain Rule Extension
# Can you write out the chain rule for the case where u = f(x, y, z) and x = x(a, b), y = y(a, b), and z = z(a, b)?

# %% [markdown]
# ## 10. Inverse Function Derivative
# Given a function f(x) that is invertible, compute the derivative of its inverse f⁻¹(x). Here we have that f⁻¹(f(x)) = x and conversely f(f⁻¹(y)) = y. Hint: use these properties in your derivation.
