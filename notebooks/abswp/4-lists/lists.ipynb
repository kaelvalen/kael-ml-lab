# %%
[1,2,3]
# Out:
# [1, 2, 3]

# %%
['cat', 'bat', 'rat']
# Out:
# ['cat', 'bat', 'rat']

# %%
['hello', True, 5, ['a', 'b', 'c']]
# Out:
# ['hello', True, 5, ['a', 'b', 'c']]

# %%
spam = ['cat', 'bat', 'rat', 'elephant']
print(spam[1:6])
# Out:
# ['bat', 'rat', 'elephant']

# %%
spam[1]
# Out:
# 'bat'

# %%
spam[0]
# Out:
# 'cat'

# %%
'the ' + spam[1] +' eat the ' + spam[3]
# Out:
# 'the bat eat the elephant'

# %%
spam = [[1,2,3], [4,5,6], [7,8,9]]

# %%
spam[2][2]
# Out:
# 9

# %%
spam[1:2]
# Out:
# [[4, 5, 6]]

# %%
spam[-1]
# Out:
# [7, 8, 9]

# %%
spam[-1:3]
# Out:
# [[7, 8, 9]]

# %%
spam[2:]
# Out:
# [[7, 8, 9]]

# %%
spam[1] = 23

# %%
spam
# Out:
# [[1, 2, 3], 23, [7, 8, 9]]

# %%
spam * 3
# Out:
# [[1, 2, 3], 23, [7, 8, 9], [1, 2, 3], 23, [7, 8, 9], [1, 2, 3], 23, [7, 8, 9]]

# %%
spam + spam * 2
# Out:
# [[1, 2, 3], 23, [7, 8, 9], [1, 2, 3], 23, [7, 8, 9], [1, 2, 3], 23, [7, 8, 9]]

# %%
len(spam)
# Out:
# 3

# %%
catNames = []
while True:
    print('Enter the name of cat ' + str(len(catNames) + 1) + ' (Or enter nothing to stop.):')
    name = input()
    if name == '':
        break
    catNames = catNames + [name] # list concatenation
print('The cat names are:')
for name in catNames:
    print(' ' + name)
# Out:
# Enter the name of cat 1 (Or enter nothing to stop.):
# Enter the name of cat 2 (Or enter nothing to stop.):
# Enter the name of cat 3 (Or enter nothing to stop.):
# Enter the name of cat 4 (Or enter nothing to stop.):
# Enter the name of cat 5 (Or enter nothing to stop.):
# Enter the name of cat 6 (Or enter nothing to stop.):
# The cat names are:
#  rei
#  re
#  dwe
#  ef
#  rgr

# %%
catNames
# Out:
# ['rei', 're', 'dwe', 'ef', 'rgr']

# %%
for i in  [0,1,2,3,4]:
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
'reid' in catNames
# Out:
# False

# %%
cat = ['fat', 'black', 'loud']
size = cat[0]
color = cat[1]
disposition = cat[2]

# %%
color
# Out:
# 'black'

# %%
size, color, disposition = cat

# %%
cat.index('black')
# Out:
# 1

# %%
spam = ['cat', 'bat', 'rat', 'elephant']

# %%
spam.append('moose')

# %%
spam
# Out:
# ['cat', 'bat', 'rat', 'elephant', 'moose']

# %%
spam.insert(1, 'chicken')

# %%
spam
# Out:
# ['cat', 'chicken', 'bat', 'rat', 'elephant', 'moose']

# %%
spam.remove('bat')

# %%
spam
# Out:
# ['cat', 'chicken', 'rat', 'elephant', 'moose']

# %%
del spam[0]

# %%
spam
# Out:
# ['chicken', 'rat', 'elephant', 'moose']

# %%
import random
messages = ['It is certain',    
            'It is decidedly so',   
            'Yes definitely',    
            'Reply hazy try again',    
            'Ask again later',    
            'Concentrate and ask again',    
            'My reply is no',    
            'Outlook not so good',    
            'Very doubtful']
print(messages[random.randint(0, len(messages) - 1)])
# Out:
# Ask again later

# %%
name =  'Zophie'
name[0]
name[-2]
name[0:4]
# Out:
# 'Zoph'

# %%
for i in name:
    print('***' + i + '***')
# Out:
# ***Z***
# ***o***
# ***p***
# ***h***
# ***i***
# ***e***
