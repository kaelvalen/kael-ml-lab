# %%
passFile = open('Secret.txt')
secret = passFile.read()
print('enter pass')
typedPass = input()
if typedPass == secret:
    print('welcome')
    if typedPass == '12345':
        print('that is a very bad password')
else:
    print('go away')
# Out:
# enter pass
# welcome
# that is a very bad password

# %%
print('hello world')
# Out:
# hello world

# %%
'42' + 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 '42' + 3
#
# TypeError: can only concatenate str (not "int") to str
